# %%
def fun1(s):
    ''' This function returns the length of given string'''
    if type(s)==str:
        count=0
        for i in s:
            count=count+1
        return count
fun1("Teststring")
# Out:
# 10

# %%
def fun2(l):
    '''This function will return the index of all the premitive element you pass'''
    if type(l)==list or type(l)==tuple or type(l)==str:
        for i in range(len(l)):
            print(f"Index of {l[i]} is {i}")
fun2([34,4324,32,"sudh",432])
# Out:
# Index of 34 is 0
# Index of 4324 is 1
# Index of 32 is 2
# Index of sudh is 3
# Index of 432 is 4

# %%
def fun3(dg1):
    '''This function will take input as dictionary and gives out as a list of all the values
    even in case of any number of levels of nesting it will work'''
    lst=[]
    fun3b(dg1,lst)
    return lst

def fun3a(dg2):
    '''This function returns the values of the given dictionary'''
    return dg2.values()

def fun3b(dg3,lst):
    '''This function unwraps the nested dictionary and returns list of values'''
 #   print(lst)
    if type(dg3)==dict:
        a=fun3a(dg3)
        for i in a:
#            print(i)
            if type(i)==dict:
                b=fun3b(i,lst)
            else:
                lst.append(i)
            
 #   print(lst)        
    return lst
                    
fun3({"a":4,"b":6,"c":{"d":7,"e":8,"f":{"g":5,"h":8,"i":{"j":4,"k":9}}}})
# Out:
# [4, 6, 7, 8, 5, 8, 4, 9]

# %%
def fun4a(n):
    '''This function generates the n range of numbers'''
    return list(range(n))
def fun4(fun):
    '''This function takes another function as input and gives the list of numbers as output'''
    if type(fun)==list:
        l=[]
        for i in fun:
            l.append(i+2)
        return l
fun4(fun4a(5))
# Out:
# [2, 3, 4, 5, 6]

# %%
sudhanshu@ineuron.ai

# %%
def fun5(*args):
    '''This function takes n number of lists as input and gives the concantination of all
    the list element as one list'''
    l=[]
    for i in args:
        if type(i)==list:
            l=l+i
    return l

fun5([1,2,3,4,5],['a','b','c','d','e'],[11,12,13,14,15],["aa",'bb','cc','dd'],'sudh','abcd',5435)
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  11,
#  12,
#  13,
#  14,
#  15,
#  'aa',
#  'bb',
#  'cc',
#  'dd']

# %%
def fun6(lst1):
    '''This function takes list as input and return an index of each element like a inbult
    index function but even if we have repetative element it should retrun index'''
    l=[]
    if type(lst1)==list:
        for i in range(len(lst1)):
            l.append(f'Index of {lst1[i]} is {i}')
    return l
fun6([1,2,3,43.5,5])
# Out:
# ['Index of 1 is 0',
#  'Index of 2 is 1',
#  'Index of 3 is 2',
#  'Index of 43.5 is 3',
#  'Index of 5 is 4']

# %%
def fun7(path1):
    '''This function takes the directory path string as input and returns all the file name from
    given directory'''
    import os
    return os.listdir(path1)
fun7('D:\\user\\jupyternotes\\Praketh class')
# Out:
# ['.ipynb_checkpoints',
#  '1-Python basics.ipynb',
#  '2-String, tab, join, list.ipynb',
#  '3-Tuple Set dictionary.ipynb',
#  '4-For loop .ipynb',
#  '5-for loop, iterator, generators.ipynb',
#  '6-function.ipynb',
#  'my-new-folder',
#  'my-new-folder4-renamed',
#  'my-new-folder5-renamed',
#  'Praketh .ipynb',
#  'Praketh copy.ipynb',
#  'Praketh folder',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
def fun8():
    '''
    This funtion will be able to show your system configuration
    '''
    import platform as pl
    return pl.uname()
fun8()
# Out:
# uname_result(system='Windows', node='LAPTOP-U7SEIBRD', release='10', version='10.0.22000', machine='AMD64', processor='Intel64 Family 6 Model 158 Stepping 10, GenuineIntel')

# %%
def fun9():
    '''
    This function will be able to show date and time
    '''
    import subprocess as sb
    from subprocess import time
    a=time.localtime()
    Date=str(a[0])+'-'+str(a[1])+'-'+str(a[2])
    Time=str(a[3])+':'+str(a[4])+':'+str(a[5])
    return f"The Date is {Date} and the Time is {Time}"
fun9()
# Out:
# 'The Date is 2022-1-6 and the Time is 4:40:5'

# %%
def fun10(filename):
    '''
    This function will be abel to read a image file and show it to you
    '''
    import PIL
    from PIL import Image
    img=Image.open(filename,'r')
    return display(img)
file_name=input("Please enter the png file name along with .png extention: ")
fun10(file_name)
# Out:
# Please enter the png file name along with .png extention: myimage.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=637x615 at 0x23705DC5AC8>

# %%
def fun12(src_path,dst_path):
    '''
    This function will move a file from one directory to another directory
    '''
    import shutil
    shutil.move(src_path,dst_path)
    
src_path=input("Please enter the source directory path")
dst_path=input("please enter the destination directory path")

fun12(src_path,dst_path)
# Out:
# Please enter the source directory pathD:\\user\\jupyternotes\\Praketh class\\Source_directory
# please enter the destination directory pathD:\\user\\jupyternotes\\Praketh class\\Destination directory

# %%
def fun13():
    '''
    This function will shutdown your system
    '''
    import os
    os.system("shutdown /s /t 1")
fun13()

# %%
def fun16(filename):
    '''
    This function will read a complete pdf file
    '''
    import PyPDF2
    f=open(filename+'.pdf','rb')
    f_read=pdf.PdfFileReader(f)
    f_page=f_read.getPage(0)
    print(f_page.extractText())
    
filename=input("Please enter the pdf file name")

fun16(filename)
# Out:
# Please enter the pdf file namePA 3-C-6-Syllabus
# Date
# Day
# 6Th Std
# PORTIONS
# .
#
#
# .
# ,
# .
#
# -
# 3
# Shloka
# ,
# -
#
# (
#
# )
# ,
# ,
# Computer: Formatting in Excel
#               Formula in Excel (types of Formula)
# 7/1/2022
# Fri
# Social Science
# 1. Major domains of the Earth
# 2. Ashoka the emperor who gave up the war
#    3. Panchayati Raj
#        4. Vital Villages, Thriving towns
# 8/1/2022
# 9/1/2022
# 10/1/2022
# Mon
# Math
# 1. Algebra           2. Fractions          3. Decimals
# 4.Understanding elementary shapes
# 11/1/2022
# Tue
# II Lang
# :
#
# :
#
#
#
#
# :
#
#
# ,
#
# .
#
#
# :
#
# .
# ,
# ,
#
# .
#
#
#
# -
# -
# ,
# -
# ,
#
#
# ,
#
#
#
#
#
# *
#
#
# -
#
#
# -
# 26
# 40
# *
# -
#
# -
#
# ,
#
# ,
# -
#
#
#
# -
# ,
# *
#
#
# -
#
# ,
#
# ,
#
#
# *
#
# 12/1/2022
# Wed
# English
# *Reading Comprehension
# * Creative Writing
# : 1. Newspaper Report
#                                        2. Narrative Essay
# *Grammar:
#  1. Verbs
# ...

# %%
def fun17(filename):
    '''
    This function will read a complete word file
    '''
    f=open(filename+'.doc','r')
    print(f.read())
    
filename=input('Please enter the word file name without extention: ')

fun17(filename)
# Out:
# Please enter the word file name without extention: Mywordfile
# Testing the reading of word document file
# This is a second line in my word document
# This is a third line in my word document
# This is a fourth line in my word document
#
#
#
#
#
# This is a last line in my word document

# %%
def fun18(file_path):
    '''
    This function will help you to filter only word file from a directory
    '''
    import os
    a=os.walk(file_path)
    l=[]
    dir_lst=list(a)
    
    import re
    pattern=re.compile(r"\.doc$")
    
    for lst in dir_lst:
        if type(lst)==tuple:
            for dirct in lst:
                if type(dirct)==list:
                    for file in dirct:
                        matches=pattern.finditer(file)
                        for match in matches:
                            l.append(file)
    return l,dir_lst

directory_path=input("Please enter the Directory path to list all .doc files in it: ")
doc_list,dir_list=fun18(directory_path)
print("\nList of all .doc files are:\n", doc_list)
print("\n")
print("List of all files in the directory: \n", dir_list)
# Out:
# Please enter the Directory path to list all .doc files in it: D:\\user\\jupyternotes\\Praketh class
#
# List of all .doc files are:
#  ['Mywordfile.doc', 'tertew.doc', 'werew.doc', 'type.doc', 'xyz.doc', 'ewq111.doc']
#
#
# List of all files in the directory:
# ...

# %%
def fun19():
    '''
    This function will print the IP address of your system
    '''
    
    import socket
    name=socket.gethostname()
    IP_address=socket.gethostbyname(name)
    print(f"System name is {name} and IP address is {IP_address}")
fun19()
# Out:
# System name is LAPTOP-U7SEIBRD and IP address is 192.168.29.20

# %%
def fun20(filename1,filename2,filename3):
    '''
    This function will be able to append two pdf files to a new file
    '''
    import PyPDF2 as pdf
    
    f1=open(filename1+'.pdf','rb')
    f2=open(filename2+'.pdf','rb')
    f3=open(filename3+'.pdf','wb')
    
    f1_read=pdf.PdfFileReader(f1)
    f2_read=pdf.PdfFileReader(f2)
    
    f_writer=pdf.PdfFileWriter()
    
    for page_no in range(f1_read.numPages):
        f1_pages=f1_read.getPage(page_no)
        f_writer.addPage(f1_pages)
    for page_no in range(f2_read.numPages):
        f2_pages=f2_read.getPage(page_no)
        f_writer.addPage(f2_pages)
    
    f_writer.write(f3)
    
    f1.close()
    f2.close()
    f3.close()

file_1=input("Please enter the first PDF file name: ")
file_2=input("Please enter the second PDF file name: ")
file_3=input("Please enter the new PDF file name to be created: ")

fun20(file_1,file_2,file_3)
# Out:
# Please enter the first PDF file name: File1
# Please enter the second PDF file name: File2
# Please enter the new PDF file name to be created: File3
